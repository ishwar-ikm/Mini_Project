# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('../../data processing/preprocessed.csv')

# %%
df.head()
# Out:
#    Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustDir  \
# 0        30     13.4     22.9       0.6          2.4       8.3          4.0
# 1        30      7.4     25.1       0.0          3.6      10.0          2.0
# 2        30     12.9     25.7       0.0          2.6       4.4          5.0
# 3        30      9.2     28.0       0.0         14.6       8.9         11.0
# 4        30     17.5     32.3       1.0          5.4       3.0          4.0
#
#    WindGustSpeed  WindDir9am  WindDir3pm  ...  Humidity3pm  Pressure9am  \
# 0           44.0         5.0         3.0  ...         22.0       1007.7
# 1           44.0         0.0         6.0  ...         25.0       1010.6
# 2           46.0         5.0         6.0  ...         30.0       1007.6
# 3           24.0        13.0        14.0  ...         16.0       1017.6
# 4           41.0        12.0         0.0  ...         33.0       1010.8
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow  \
# 0       1007.1       8.0       0.0     16.9     21.8      False         False
# 1       1007.8       7.0       1.0     17.2     24.3      False         False
# 2       1008.7       8.0       2.0     21.0     23.2      False         False
# 3       1012.8       0.0       5.0     18.1     26.5      False         False
# 4       1006.0       7.0       8.0     17.8     29.7      False         False
#
#    Date_month
# 0          12
# 1          12
# 2          12
# 3          12
# 4          12
#
# [5 rows x 23 columns]

# %%
X = df.drop('RainTomorrow', axis=1)

# %%
y = df['RainTomorrow']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
def report_model(model):
    model_preds = model.predict(X_test)
    print(classification_report(y_test, model_preds))
    print('\n')
    print(pd.DataFrame(index=X.columns, data=model.feature_importances_, columns=['Feature Importance']).sort_values(['Feature Importance']))
    print('\n')
    # plt.figure(figsize=(12,8), dpi=200)
    # plot_tree(model, feature_names=X.columns, filled=True)

# %%
from sklearn.tree import plot_tree
from sklearn.metrics import classification_report, confusion_matrix

# %%
report_model(model)
# Out:
#               precision    recall  f1-score   support
#
#        False       0.87      0.85      0.86     34058
#         True       0.50      0.54      0.52      9580
#
#     accuracy                           0.78     43638
#    macro avg       0.68      0.69      0.69     43638
# weighted avg       0.79      0.78      0.78     43638
#
#
#
#                Feature Importance
# RainToday                0.001129
# Cloud9am                 0.021980
# Cloud3pm                 0.022521
# Date_month               0.023019
# WindDir9am               0.025725
# Rainfall                 0.026876
# WindGustDir              0.027090
# WindDir3pm               0.028111
# WindSpeed9am             0.030549
# WindSpeed3pm             0.033103
# MaxTemp                  0.034611
# Temp3pm                  0.035176
# Temp9am                  0.038935
# Evaporation              0.039633
# Location                 0.041797
# Pressure9am              0.042156
# MinTemp                  0.042361
# Humidity9am              0.042865
# Sunshine                 0.050788
# Pressure3pm              0.064353
# WindGustSpeed            0.065130
# Humidity3pm              0.262091
